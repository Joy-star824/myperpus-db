# %%
from openpyxl import load_workbook
import pandas as pd

# %%
import os
folder = "/content/drive/MyDrive/komentar_seller.xlsx"
print(os.listdir(folder))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3044580473.py in <cell line: 0>()
#       1 import os
#       2 folder = "/content/drive/MyDrive/komentar_seller.xlsx"
# ----> 3 print(os.listdir(folder))
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/komentar_seller.xlsx'
